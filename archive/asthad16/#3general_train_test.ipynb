# %% [markdown]
# IMPORTING NECESSARY PACKAGES AND MODULES

# %%
import pandas as pd
from data_preprocess import *
from train_test import *
from evaluation import *
from data_exploration import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from knn_classifier import *

# %% [markdown]
# READING THE CSV FILE

# %%
df = pd.read_csv("../../../datasets/winequality.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  recommend
# 0      8.8        6      False
# 1      9.5        6      False
# 2     10.1        6      False
# 3      9.9        6      False
# 4      9.9        6      False

# %% [markdown]
# PREPROCESSING RECOMMEND ATTRIBUTE (TRUE-1,FALSE-0) CHANGING TO NUMERICAL FROM CATEGORICAL

# %%
process_binary(df)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  recommend
# 0         8.8        6          0
# 1         9.5        6          0
# 2        10.1        6          0
# 3         9.9        6          0
# 4         9.9        6          0
# ...       ...      ...        ...
# 4893     11.2        6          0
# 4894      9.6        5          0
# 4895      9.4        6          0
# 4896     12.8        7          1
# 4897     11.8        6          0
#
# [4898 rows x 13 columns]

# %% [markdown]
# features-LIST WITH DEPENDENT VARIABLES target1-target variable

# %%
features = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density', 'pH','sulphates','alcohol']
target1 = ['recommend']

# %% [markdown]
# SEPARATING THE DEPENDENT AND INDEPENDENT VARIABLES

# %%
x = df[features]
y1 = df[target1].values.ravel()

# %% [markdown]
# # accuracy variation with different train test split ratio with KNN model

# %% [markdown]
# this function does following things:
#
# 1-holdout validation of dataset by splitting in training and testing set
#
# 2-applying KNN model with parameters as no. of neighbours is 5 and weighing criteria is uniform.
#
# 3- main aim is doing multiple train- test split and evaluate accucracy thus we can be sure that our model is stable or not over fitted on training data.
#
# 4-this highlights the importance of choosing suitable train-test ratio for good accuracy score of our model.
#
# result obtained:
# the accuracy is highest with train-test split ratio of 60:40 of 78.3673%.

# %%
 classifier = KNeighborsClassifier(n_neighbors=5, weights='uniform')

# %%
df1 = split_table(classifier,x,y1)
df1
# Out:
#     train_set(%)  test_set(%)   accuracy  f1_score  precision_score  \
# 0           95.0          5.0  74.285714  0.363636         0.450000
# 1           94.0          6.0  75.850340  0.382609         0.468085
# 2           93.0          7.0  76.384840  0.381679         0.480769
# 3           92.0          8.0  76.275510  0.375839         0.474576
# 4           91.0          9.0  75.736961  0.381503         0.485294
# 5           90.0         10.0  76.530612  0.391534         0.468354
# 6           89.0         11.0  77.551020  0.403941         0.493976
# 7           88.0         12.0  78.061224  0.426667         0.521739
# 8           87.0         13.0  78.178964  0.446215         0.533333
# 9           86.0         14.0  77.551020  0.429630         0.527273
# 10          85.0         15.0  77.142857  0.424658         0.525424
# 11          84.0         16.0  76.785714  0.420382         0.536585
# 12          83.0         17.0  76.830732  0.423881         0.529851
# 13          82.0         18.0  76.530612  0.416901         0.510345
# 14          81.0         19.0  77.228786  0.430108         0.529801
# 15          80.0         20.0  77.551020  0.427083         0.522293
# 16          79.0         21.0  76.967930  0.423358         0.514793
# 17          78.0         22.0  77.087199  0.421546         0.505618
# 18          77.0         23.0  77.462289  0.412037         0.511494
# 19          76.0         24.0  77.295918  0.410596         0.510989
# 20          75.0         25.0  77.714286  0.430063         0.528205
# 21          74.0         26.0  77.864992  0.426829         0.517241
# 22          73.0         27.0  77.702192  0.424951         0.511737
# 23          72.0         28.0  77.405248  0.417293         0.502262
# 24          71.0         29.0  77.339901  0.412409         0.500000
# 25          70.0         30.0  77.551020  0.412811         0.497854
# 26          69.0         31.0  77.682686  0.410435         0.502128
# 27          68.0         32.0  77.742347  0.413445         0.506173
# 28          67.0         33.0  77.922078  0.417618         0.507937
# 29          66.0         34.0  78.031212  0.405844         0.508130
# 30          65.0         35.0  77.725948  0.397476         0.500000
# 31          64.0         36.0  77.891156  0.398148         0.507874
# 32          63.0         37.0  77.992278  0.396369         0.515748
# 33          62.0         38.0  78.034372  0.395864         0.517375
# 34          61.0         39.0  78.440607  0.399417         0.526923
# 35          60.0         40.0  78.367347  0.401130         0.518248
# 36          59.0         41.0  78.148333  0.397805         0.506993
# 37          58.0         42.0  77.793975  0.397892         0.500000
# 38          57.0         43.0  77.693403  0.402036         0.501587
# 39          56.0         44.0  77.504638  0.397516         0.496894
# 40          55.0         45.0  77.732426  0.403402         0.506098
# 41          54.0         46.0  77.595386  0.398093         0.498507
# 42          53.0         47.0  77.377334  0.393481         0.494152
# 43          52.0         48.0  77.465986  0.387991         0.497041
# 44          51.0         49.0  77.467722  0.380298         0.501511
# 45          50.0         50.0  77.051858  0.372768         0.498507
#
#     recall_score
# 0       0.305085
# 1       0.323529
# 2       0.316456
# 3       0.311111
# 4       0.314286
# 5       0.336364
# 6       0.341667
# 7       0.360902
# 8       0.383562
# 9       0.362500
# 10      0.356322
# 11      0.345550
# 12      0.353234
# 13      0.352381
# 14      0.361991
# 15      0.361233
# 16      0.359504
# 17      0.361446
# 18      0.344961
# 19      0.343173
# 20      0.362676
# 21      0.363322
# 22      0.363333
# 23      0.356913
# 24      0.350932
# 25      0.352584
# 26      0.347059
# 27      0.349432
# 28      0.354571
# 29      0.337838
# 30      0.329843
# 31      0.327411
# 32      0.321867
# 33      0.320574
# 34      0.321596
# 35      0.327189
# 36      0.327314
# 37      0.330416
# 38      0.335456
# 39      0.331263
# 40      0.335354
# 41      0.331349
# 42      0.326886
# 43      0.318182
# 44      0.306273
# 45      0.297683

# %%
graph(df1,"test_set(%)","accuracy","accuracy variation with test split")

# %% [markdown]
# # applying KNN model with hyper parameter tuning .

# %% [markdown]
# applying KNN model with hyper parameter tuning for the value of k and weighting criteria to choose suitable parametric values to inhance overall perforamance of model taking train-test ratio 60:40 obtained from above analysis.

# %%
X_train, X_test, y_train, y_test = data_split(x,y1,0.40)

# %% [markdown]
# using grid search CV for getting suitable values of k(no. of neighbours around a data point) and weight criteria(method for choosing most closely related neighbour) with 10 fold validation.

# %%
grid_knn(X_train, y_train)
# Out:
# {'n_neighbors': 30, 'weights': 'distance'}

# %% [markdown]
# using obtained value of k and weight criteria and evaluating the results.obtained accuracy is 84.2857 quite great than one with decision tree of 80.075%.
#
# 1- 1652 out of 1960 samples are correctly classified.
# 2- 1494 samples are recommended.
# 3- 158 sample are not recommended.
# 4- 32 samples that were not recommended(false) are classfied as true.
# 5- 276 samples that were recommended(true) are classified as false.

# %%
y_pred,y_prob = knn_class(X_test,X_train,y_train,30,"distance")
print( "Accuracy of with KNN classifier is: ", acc_score(y_test,y_pred))
print ("\nclassification report:" , report(y_test,y_pred))
print ("\nconfusion matrix:",matrix(y_test,y_pred))
# Out:
# Accuracy of with KNN classifier is:  84.28571428571429
#
# classification report:               precision    recall  f1-score   support
#
#        False       0.84      0.98      0.91      1526
#         True       0.83      0.36      0.51       434
#
#     accuracy                           0.84      1960
#    macro avg       0.84      0.67      0.71      1960
# weighted avg       0.84      0.84      0.82      1960
#
#
# confusion matrix: [[1494   32]
#  [ 276  158]]

# %% [markdown]
# # accuracy variation with different train test split ratio with decision tree model

# %% [markdown]
# this function does following things:
#
# 1-holdout validation of dataset by splitting in training and testing set
#
# 2-applying decision tree model with hyper  parameter tuning obtained from task#2wine_quality notebook.
#
# max depth is 6
#
# min_samples_leaf are 2
#
# used impurity criteria is gini.
#
# 3- main aim is doing multiple train- test split and evaluate accucracy thus we can be sure that our model is stable or not over fitted on training data.
#
# 4-this highlights the importance of choosing suitable train-test ratio for good accuracy score of our model.
#
# result obtained:
# the accuracy is highest with train-test split ratio of 51:49 of 80.75%.

# %%
classifier = DecisionTreeClassifier(
        criterion="gini",
        splitter="random",
        random_state=42,
        max_depth=6,
        min_samples_leaf=2,
    )

# %%
df2 = split_table(classifier,x,y1)
df2
# Out:
#     train_set(%)  test_set(%)   accuracy  f1_score  precision_score  \
# 0           95.0          5.0  79.183673  0.301370         0.785714
# 1           94.0          6.0  76.870748  0.451613         0.500000
# 2           93.0          7.0  78.425656  0.339286         0.575758
# 3           92.0          8.0  79.081633  0.327869         0.625000
# 4           91.0          9.0  78.684807  0.328571         0.657143
# 5           90.0         10.0  80.000000  0.371795         0.630435
# 6           89.0         11.0  80.519481  0.385965         0.647059
# 7           88.0         12.0  78.571429  0.422018         0.541176
# 8           87.0         13.0  79.120879  0.448133         0.568421
# 9           86.0         14.0  79.008746  0.470588         0.571429
# 10          85.0         15.0  78.639456  0.467797         0.570248
# 11          84.0         16.0  79.209184  0.485804         0.611111
# 12          83.0         17.0  79.471789  0.489552         0.611940
# 13          82.0         18.0  79.705215  0.484150         0.613139
# 14          81.0         19.0  78.410311  0.430595         0.575758
# 15          80.0         20.0  79.387755  0.317568         0.681159
# 16          79.0         21.0  79.980564  0.371951         0.709302
# 17          78.0         22.0  80.333952  0.369048         0.712644
# 18          77.0         23.0  80.567879  0.368876         0.719101
# 19          76.0         24.0  80.612245  0.377049         0.726316
# 20          75.0         25.0  79.102041  0.438596         0.581395
# 21          74.0         26.0  81.004710  0.379487         0.732673
# 22          73.0         27.0  80.498866  0.460251         0.617978
# 23          72.0         28.0  79.956268  0.364896         0.647541
# 24          71.0         29.0  80.506685  0.351288         0.714286
# 25          70.0         30.0  79.047619  0.355649         0.570470
# 26          69.0         31.0  78.933509  0.349593         0.565789
# 27          68.0         32.0  78.890306  0.420315         0.547945
# 28          67.0         33.0  80.333952  0.331933         0.686957
# 29          66.0         34.0  80.372149  0.328542         0.683761
# 30          65.0         35.0  80.174927  0.325397         0.672131
# 31          64.0         36.0  79.818594  0.408638         0.591346
# 32          63.0         37.0  78.599007  0.412121         0.537549
# 33          62.0         38.0  78.410311  0.408824         0.530534
# 34          61.0         39.0  78.911565  0.406480         0.545455
# 35          60.0         40.0  79.846939  0.391371         0.590698
# 36          59.0         41.0  80.487805  0.346667         0.662420
# 37          58.0         42.0  79.251701  0.428380         0.551724
# 38          57.0         43.0  79.401993  0.436364         0.561873
# 39          56.0         44.0  79.591837  0.385475         0.592275
# 40          55.0         45.0  79.365079  0.390897         0.579365
# 41          54.0         46.0  79.281278  0.381457         0.573705
# 42          53.0         47.0  79.287885  0.387677         0.576336
# 43          52.0         48.0  79.719388  0.403004         0.594096
# 44          51.0         49.0  80.758017  0.400000         0.675439
# 45          50.0         50.0  78.848510  0.447761         0.557029
#
#     recall_score
# 0       0.186441
# 1       0.411765
# 2       0.240506
# 3       0.222222
# 4       0.219048
# 5       0.263636
# 6       0.275000
# 7       0.345865
# 8       0.369863
# 9       0.400000
# 10      0.396552
# 11      0.403141
# 12      0.407960
# 13      0.400000
# 14      0.343891
# 15      0.207048
# 16      0.252066
# 17      0.248996
# 18      0.248062
# 19      0.254613
# 20      0.352113
# 21      0.256055
# 22      0.366667
# 23      0.254019
# 24      0.232919
# 25      0.258359
# 26      0.252941
# 27      0.340909
# 28      0.218837
# 29      0.216216
# 30      0.214660
# 31      0.312183
# 32      0.334152
# 33      0.332536
# 34      0.323944
# 35      0.292627
# 36      0.234763
# 37      0.350109
# 38      0.356688
# 39      0.285714
# 40      0.294949
# 41      0.285714
# 42      0.292070
# 43      0.304924
# 44      0.284133
# 45      0.374332

# %%
graph(df2,"test_set(%)","accuracy","accuracy variation with test split")
