# %% [markdown]
# # PRESC Report

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
# Load the inputs to the report.
#
# This creates:
# - the Dataset instance `dataset`
# - the ClassificationModel instance `cm`
# - a dict of config options `config`.
#
# Imports are also all managed from here.

# %run setup_report.py

# %% [markdown]
# ## Dataset

# %%
dataset.df.head()

# %%
print(f"{len(dataset.feature_names)} features:\n")
print(dataset.features.dtypes)

# %%
print(f"Training set size: {train_dataset.size:,}")
print(
    f"Test set size: {test_dataset.size:,}" +
    f" ({test_dataset.size / train_dataset.size:.1%})"
)

# %% [markdown]
# ## Classifier

# %%
cm.classifier

# %% [markdown]
# ## Top level metrics

# %%
print(classification_report(test_dataset.labels, cm.predict_labels(test_dataset)))

# %%
_ = plot_confusion_matrix(cm.classifier, test_dataset.features, test_dataset.labels)
