# %% [markdown]
# ## Conditional feature distribution
#
# This shows the distribution of features across different quadrants in the confusion matrix.

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

from presc.conditional_feature_distribution.conditional_feature_distribution import plot_all_histogram_conditional_feature_distribution

# %%
# TOOD: how to share state between notebooks

# %run setup_report.py

# %%
# Run a simple SVC classifier
scaler = StandardScaler().fit(cm.dataset.train_features)

classifier = SVC(kernel="linear", decision_function_shape="ovo")
classifier.fit(scaler.transform(cm.dataset.train_features), cm.dataset.train_labels)
y_predict = classifier.predict(scaler.transform(cm.dataset.test_features))

# %%
plot_all_histogram_conditional_feature_distribution(
    y_predict = cm.test_predictions, 
    feature_column = cm.dataset.test_features.pH, 
    y_actual = cm.dataset.test_labels, 
    bins = None
);
