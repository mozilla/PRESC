# %% [markdown]
# ## Train-test splits
#
# This shows how the given scoring metric varies across different potential train-test split proportions.

# %%
from presc.evaluations.train_test_splits import TrainTestSplits
from presc.report.runner import Context

# Better quality plots
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("svg")

# %%
# Load inputs from data store in cwd.
ctx = Context()
train_dataset = ctx.train_dataset
cm = ctx.model
config = ctx.config

# %%
e = TrainTestSplits(cm, train_dataset, config=config)

# %%
e.display()
