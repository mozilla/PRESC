# %% [markdown]
# ## Examining the relation between Data Split and Evaluation Metrics

# %%
from data_split_examine import data_split_examine, visualise_split
from IPython.display import Markdown, display
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
classifiers = ['svm_classifier', 'KNeighbors', 'Logistic_Reg', 'Decision_Tree', 'Random_Forest', 'Gaussian']

# %%
for clf in classifiers:
    display(Markdown('**'+ clf+'**'))
    data_split_examine(clf)
    visualise_split(clf)
# Out:
# **svm_classifier**
#     Training data  Testing Data  Accuracy %  Precision  Recall  F1_score
# 1           100.0           0.0   64.000000   0.640000     1.0  0.780488
# 2            94.0           6.0   54.733010   0.547330     1.0  0.707451
# 3            90.0          11.0   56.134774   0.561348     1.0  0.719055
# 4            84.0          16.0   56.933678   0.569337     1.0  0.725576
# 5            80.0          20.0   56.659069   0.566591     1.0  0.723342
# 6            74.0          26.0   56.297460   0.562975     1.0  0.720389
# 7            70.0          31.0   55.385289   0.553853     1.0  0.712877
# 8            64.0          36.0   54.936995   0.549370     1.0  0.709153
# 9            60.0          40.0   54.962084   0.549621     1.0  0.709362
# 10           54.0          46.0   55.011005   0.550110     1.0  0.709769
# 11           50.0          50.0   54.898850   0.548988     1.0  0.708835
# 12           44.0          56.0   55.004812   0.550048     1.0  0.709717
# ...
