# %% [markdown]
# ## Examining the split between Data Split and Evaluation Metrics

# %%
from dataloader import data_info, train_test_split_data, data_visuals
from classifiers import Classifier
from data_split_examine import data_split_examine, visualise_split

# %%
data_split_examine()
# Out:
#     Training data  Testing Data  Accuracy %  Precision    Recall  F1_score
# 1           100.0           0.0   94.666667   0.958333  0.958333  0.958333
# 2            94.0           6.0   96.359223   0.970917  0.962306  0.966592
# 3            90.0          11.0   96.185633   0.975723  0.955832  0.965675
# 4            84.0          16.0   96.124031   0.976043  0.955371  0.965596
# 5            80.0          20.0   96.190166   0.973730  0.958621  0.966116
# 6            74.0          26.0   95.705682   0.967514  0.955814  0.961628
# 7            70.0          31.0   95.446585   0.961080  0.956522  0.958796
# 8            64.0          36.0   95.448561   0.958890  0.958233  0.958562
# 9            60.0          40.0   95.070887   0.954750  0.955609  0.955179
# 10           54.0          46.0   95.011005   0.952482  0.957055  0.954763
# 11           50.0          50.0   94.975539   0.952278  0.956407  0.954338
# 12           44.0          56.0   94.694418   0.948729  0.955162  0.951935
# 13           39.0          61.0   94.194901   0.944234  0.950672  0.947442
# 14           34.0          66.0   93.628950   0.939790  0.944835  0.942306
# 15           29.0          70.0   93.058055   0.934395  0.939707  0.937044
# 16           24.0          76.0   92.004953   0.921410  0.934713  0.928014
# 17           19.0          80.0   90.826145   0.907291  0.928818  0.917928
# 18           14.0          86.0   89.597813   0.894976  0.919530  0.907087
# 19            9.0          90.0   87.450199   0.876428  0.900147  0.888129
# 20            4.0          96.0   82.297420   0.820967  0.868794  0.844204

# %%
visualise_split()
