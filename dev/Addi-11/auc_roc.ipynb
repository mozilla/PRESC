# %%
from auc_roc import auc_roc
from classifiers import Classifier
from dataloader import train_test_split_data

# %%
X_train, X_test, y_train, y_test = train_test_split_data(0.33)

# %%
model = Classifier()
clf = model.Gaussian(X_train, y_train)
y_score = clf.predict(X_test)

auc_roc(y_test, y_score)
# Out:
# /home/aditi/.local/lib/python3.8/site-packages/sklearn/naive_bayes.py:206: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0
# 1

# %%
clf = model.svm_classifier(X_train, y_train)
y_score = clf.predict(X_test)

auc_roc(y_test, y_score)
# Out:
# /home/aditi/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
