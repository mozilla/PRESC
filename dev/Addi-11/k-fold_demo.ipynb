# %%
from kfold_map import perform_repeated_cv, plot_kfold_graph
from classifiers import Classifier
from dataloader import train_val_test_split_data, get_x_y

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
x_train, x_val, _, y_train, y_val,_ = train_val_test_split_data(0.2)
model = Classifier()
clf = model.KNeighbors(x_train, y_train)

# %%
perform_repeated_cv(clf)
# Out:
# (array([0.95959933, 0.95926544, 0.9542571 , 0.95592654, 0.95559265,
#         0.9542571 , 0.96126878, 0.95292154, 0.96227045, 0.96360601,
#         0.96160267, 0.95392321, 0.95826377, 0.96594324, 0.95859766,
#         0.95792988, 0.96026711, 0.96427379, 0.95826377, 0.95926544,
#         0.960601  , 0.95792988, 0.9572621 , 0.96494157, 0.95592654,
#         0.95893155, 0.96494157, 0.96494157, 0.96193656, 0.96193656,
#         0.96560935, 0.96227045, 0.96494157, 0.96093489, 0.95993322,
#         0.95759599, 0.95893155, 0.96093489, 0.96293823, 0.96594324,
#         0.96494157, 0.96327212, 0.95826377, 0.96227045, 0.96126878,
#         0.95525876, 0.96327212, 0.96260434, 0.96227045, 0.96293823]),
#  array([0.96069089, 0.96050269, 0.95542169, 0.95581114, 0.96065375,
#         0.95723885, 0.95756127, 0.95785671, 0.96111786, 0.96650718,
#         0.96123561, 0.95160315, 0.95438389, 0.96568047, 0.95610343,
#         0.96097561, 0.96207104, 0.96533174, 0.96016647, 0.96059701,
#         0.96516517, 0.95997574, 0.96107056, 0.96432818, 0.9500902 ,
#         0.95969176, 0.96888347, 0.96403302, 0.9645006 , 0.96327014,
#         0.96375921, 0.96839595, 0.96135553, 0.95940959, 0.96334135,
#         0.9568434 , 0.95862884, 0.95945946, 0.96415771, 0.96642686,
#         0.9676453 , 0.96943765, 0.95770393, 0.96348144, 0.96280744,
#         0.95345989, 0.96902918, 0.9623086 , 0.96782028, 0.96426444]),
#  array([0.96702638, 0.96628537, 0.96179503, 0.96398046, 0.95891239,
#         0.95899633, 0.9726776 , 0.95728039, 0.96995708, 0.96824446,
#         0.96886447, 0.96443899, 0.97106691, 0.97374702, 0.96892139,
#         0.96214896, 0.96614268, 0.97055288, 0.96533174, 0.96636637,
#         0.9640072 , 0.96348144, 0.96107056, 0.9730054 , 0.9699202 ,
#         0.96714456, 0.96711328, 0.97379392, 0.9668275 , 0.96901073,
#         0.97272164, 0.96437055, 0.97585999, 0.96834264, 0.9645006 ,
#         0.96457427, 0.96835821, 0.9683819 , 0.96936937, 0.97225573,
#         0.96938776, 0.963548  , 0.96646341, 0.96760391, 0.96745027,
#         0.96408669, 0.96557864, 0.97146254, 0.9637243 , 0.96946108]))

# %%
plot_kfold_graph()
