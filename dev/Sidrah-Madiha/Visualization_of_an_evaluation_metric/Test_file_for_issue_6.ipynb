# %%
import pandas as pd
import metric_evaluation_plot as visual_metric

# %%
## Creating test dataframe
import pandas as pd
df = pd.DataFrame(columns=['x', 'y0', 'y1', 'y2', 'y4'])
to_append = [['A', 0.1,0.02,0.13,0.14], ['B', 0.05,0.16,0.07,0.81], ['C',0.09, 0.10,0.11,0.12]]
df = df.append(pd.DataFrame(to_append, columns=df.columns))

df
# Out:
#    x    y0    y1    y2    y4
# 0  A  0.10  0.02  0.13  0.14
# 1  B  0.05  0.16  0.07  0.81
# 2  C  0.09  0.10  0.11  0.12

# %%
visual_metric.visualize_spread_of_metric(df)
