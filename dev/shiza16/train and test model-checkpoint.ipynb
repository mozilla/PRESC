# %% [markdown]
# <h1>Loading Dataset from Vehicle.csv<h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
vehicle = pd.read_csv('C:/Users/pcs/Documents/GitHub/PRESC/datasets/vehicles.csv')

# %%
vehicle.head(5)
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42                      20                        159
# 1             45                      19                        143
# 2             32                      23                        158
# 3             46                      19                        143
# 4             45                      19                        144
#
#    SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                    176                    379                        184
# 1                    170                    330                        158
# 2                    223                    635                        220
# 3                    160                    309                        127
# 4                    241                    325                        188
#
#    SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                    70                     6                    16
# 1                    72                     9                    14
# 2                    73                    14                     9
# 3                    63                     6                    10
# 4                   127                     9                    11
#
#    KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO Class
# 0                   187            197   van
# 1                   189            199   van
# 2                   188            196  saab
# 3                   199            207   van
# 4                   180            183   bus

# %% [markdown]
# <b> All Feature Names contain in vehicles.csv </b>

# %%
vehicle.keys()
# Out:
# Index(['COMPACTNESS', 'CIRCULARITY', 'DISTANCE_CIRCULARITY', 'RADIUS_RATIO',
#        'PR.AXIS_ASPECT_RATIO', 'MAX.LENGTH_ASPECT_RATIO', 'SCATTER_RATIO',
#        'ELONGATEDNESS', 'PR.AXIS_RECTANGULARITY', 'MAX.LENGTH_RECTANGULARITY',
#        'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR',
#        'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR',
#        'SKEWNESS_ABOUT_MINOR', 'KURTOSIS_ABOUT_MAJOR', 'KURTOSIS_ABOUT_MINOR',
#        'HOLLOWS_RATIO', 'Class'],
#       dtype='object')

# %% [markdown]
# <b>Target Class for Model</b>

# %%
vehicle['Class']
# Out:
# 0       van
# 1       van
# 2      saab
# 3       van
# 4       bus
#        ...
# 841    saab
# 842     van
# 843    saab
# 844    saab
# 845     van
# Name: Class, Length: 846, dtype: object

# %%
vehicle.shape
# Out:
# (846, 19)

# %% [markdown]
# <b>The vehicle data contains 19 Features with 846 Records</b>

# %% [markdown]
# <h1>  Data Visualization   </h1>

# %% [markdown]
# <b>Histogram for analyzing the frequency of labled class</b>

# %%
sns.countplot(vehicle['Class'])

# %% [markdown]
# <b> Correlation analysis </b>

# %%
figure = plt.gcf()
figure.set_size_inches(18, 10)
sns.heatmap(vehicle.corr(), annot = True , linewidths=.5)
plt.show()

# %% [markdown]
# <h1>  Training Model   </h1>

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# <b>Seperating training data from Target Label</b>

# %%
X = vehicle.drop(['Class'] , axis = 1)
X
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0             95           48                    83           178
# 1             91           41                    84           141
# 2            104           50                   106           209
# 3             93           41                    82           159
# 4             85           44                    70           205
# ..           ...          ...                   ...           ...
# 841           93           39                    87           183
# 842           89           46                    84           163
# 843          106           54                   101           222
# 844           86           36                    78           146
# 845           85           36                    66           123
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      72                       10            162
# 1                      57                        9            149
# 2                      66                       10            207
# 3                      63                        9            144
# 4                     103                       52            149
# ..                    ...                      ...            ...
# 841                    64                        8            169
# 842                    66                       11            159
# 843                    67                       12            222
# 844                    58                        7            135
# 845                    55                        5            120
#
#      ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0               42                      20                        159
# 1               45                      19                        143
# 2               32                      23                        158
# 3               46                      19                        143
# 4               45                      19                        144
# ..             ...                     ...                        ...
# 841             40                      20                        134
# 842             43                      20                        159
# 843             30                      25                        173
# 844             50                      18                        124
# 845             56                      17                        128
#
#      SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                      176                    379                        184
# 1                      170                    330                        158
# 2                      223                    635                        220
# 3                      160                    309                        127
# 4                      241                    325                        188
# ..                     ...                    ...                        ...
# 841                    200                    422                        149
# 842                    173                    368                        176
# 843                    228                    721                        200
# 844                    155                    270                        148
# 845                    140                    212                        131
#
#      SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                      70                     6                    16
# 1                      72                     9                    14
# 2                      73                    14                     9
# 3                      63                     6                    10
# 4                     127                     9                    11
# ..                    ...                   ...                   ...
# 841                    72                     7                    25
# 842                    72                     1                    20
# 843                    70                     3                     4
# 844                    66                     0                    25
# 845                    73                     1                    18
#
#      KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO
# 0                     187            197
# 1                     189            199
# 2                     188            196
# 3                     199            207
# 4                     180            183
# ..                    ...            ...
# 841                   188            195
# 842                   186            197
# 843                   187            201
# 844                   190            195
# 845                   186            190
#
# [846 rows x 18 columns]

# %%
y  = vehicle['Class']
y
# Out:
# 0       van
# 1       van
# 2      saab
# 3       van
# 4       bus
#        ...
# 841    saab
# 842     van
# 843    saab
# 844    saab
# 845     van
# Name: Class, Length: 846, dtype: object

# %% [markdown]
# <b>Splitting data for training and testing.</b>

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3 , random_state=45)

# %% [markdown]
# <b>Training model using Support Vector M</b>

# %%
from sklearn.svm import SVC
classifier = SVC(gamma = 'auto' , kernel = 'poly', degree = 2)
classifier.fit(X,y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=2, gamma='auto', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# <h1> Evaluating The Model</h1>

# %%
from sklearn.metrics import classification_report , confusion_matrix

# %%
#Values predicted by Classifier

y_predict = classifier.predict(X_test)
y_predict
# Out:
# array(['bus', 'saab', 'saab', 'opel', 'saab', 'van', 'opel', 'opel',
#        'opel', 'van', 'opel', 'bus', 'opel', 'saab', 'opel', 'van',
#        'saab', 'saab', 'bus', 'saab', 'bus', 'bus', 'bus', 'bus', 'bus',
#        'van', 'saab', 'opel', 'bus', 'bus', 'saab', 'opel', 'bus', 'saab',
#        'saab', 'bus', 'saab', 'saab', 'bus', 'van', 'van', 'opel', 'opel',
#        'bus', 'saab', 'van', 'bus', 'saab', 'saab', 'bus', 'bus', 'opel',
#        'saab', 'van', 'van', 'saab', 'bus', 'bus', 'opel', 'opel', 'van',
#        'van', 'bus', 'bus', 'saab', 'van', 'bus', 'bus', 'van', 'van',
#        'saab', 'opel', 'opel', 'van', 'opel', 'van', 'opel', 'opel',
#        'bus', 'bus', 'opel', 'opel', 'opel', 'van', 'bus', 'bus', 'opel',
#        'saab', 'saab', 'van', 'opel', 'van', 'van', 'saab', 'saab',
#        'opel', 'bus', 'saab', 'saab', 'bus', 'bus', 'saab', 'saab', 'bus',
#        'van', 'bus', 'opel', 'saab', 'van', 'saab', 'van', 'bus', 'opel',
#        'bus', 'opel', 'opel', 'saab', 'van', 'saab', 'saab', 'opel',
#        'saab', 'saab', 'bus', 'bus', 'saab', 'opel', 'opel', 'opel',
#        'bus', 'bus', 'bus', 'van', 'saab', 'bus', 'bus', 'opel', 'opel',
#        'opel', 'opel', 'van', 'saab', 'van', 'van', 'opel', 'bus', 'saab',
#        'saab', 'bus', 'saab', 'van', 'bus', 'bus', 'opel', 'van', 'van',
#        'van', 'bus', 'saab', 'bus', 'saab', 'saab', 'opel', 'saab', 'van',
#        'opel', 'van', 'opel', 'bus', 'opel', 'opel', 'opel', 'van', 'van',
#        'van', 'saab', 'bus', 'van', 'bus', 'bus', 'opel', 'van', 'van',
#        'saab', 'opel', 'saab', 'opel', 'saab', 'van', 'van', 'saab',
#        'bus', 'opel', 'opel', 'bus', 'bus', 'opel', 'bus', 'bus', 'bus',
#        'van', 'van', 'bus', 'bus', 'bus', 'opel', 'opel', 'van', 'van',
#        'bus', 'saab', 'bus', 'van', 'van', 'van', 'opel', 'van', 'bus',
#        'saab', 'opel', 'van', 'bus', 'bus', 'opel', 'van', 'bus', 'bus',
#        'bus', 'bus', 'saab', 'saab', 'bus', 'bus', 'bus', 'bus', 'opel',
#        'opel', 'bus', 'bus', 'van', 'bus', 'bus', 'saab', 'opel', 'saab',
#        'saab', 'bus', 'van', 'opel', 'opel', 'van', 'saab', 'bus', 'opel'],
#       dtype=object)

# %% [markdown]
# <b>Confusion Matrix</b>

# %%
cmatrix = confusion_matrix(y_test,y_predict)

# %%
figure = plt.gcf()
figure.set_size_inches(10, 5)
sns.heatmap(cmatrix, annot=True, linewidths=.5)
plt.show()

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          bus       0.97      1.00      0.99        77
#         opel       0.79      0.75      0.77        65
#         saab       0.74      0.75      0.75        57
#          van       1.00      1.00      1.00        55
#
#     accuracy                           0.88       254
#    macro avg       0.88      0.88      0.88       254
# weighted avg       0.88      0.88      0.88       254

# %% [markdown]
# <b>Accuracy of model to predict data is : 88%</b>
