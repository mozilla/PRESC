# %% [markdown]
# # Loading Dataset from Vehicle.csv

# %%
#importing python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
warnings.filterwarnings("ignore")

# %%
#importing custom python modules
import modules as Mvehicle
import ModelEvaluation as model
import VisualizationForMisclassification as visualize
import TrainTest_Split_Traversal as train_test_split

# %%
vehicle = pd.read_csv('../../datasets/vehicles.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
vehicle.head(5)
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42                      20                        159
# 1             45                      19                        143
# 2             32                      23                        158
# 3             46                      19                        143
# 4             45                      19                        144
#
#    SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                    176                    379                        184
# 1                    170                    330                        158
# 2                    223                    635                        220
# 3                    160                    309                        127
# 4                    241                    325                        188
#
#    SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                    70                     6                    16
# 1                    72                     9                    14
# 2                    73                    14                     9
# 3                    63                     6                    10
# 4                   127                     9                    11
#
#    KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO Class
# 0                   187            197   van
# 1                   189            199   van
# 2                   188            196  saab
# 3                   199            207   van
# 4                   180            183   bus

# %%
Mvehicle.dataset_statistics(vehicle)
# Out:
# Shape of the dataset:  (846, 19)
#
# Features of the dataset are:
#  ['COMPACTNESS', 'CIRCULARITY', 'DISTANCE_CIRCULARITY', 'RADIUS_RATIO', 'PR.AXIS_ASPECT_RATIO', 'MAX.LENGTH_ASPECT_RATIO', 'SCATTER_RATIO', 'ELONGATEDNESS', 'PR.AXIS_RECTANGULARITY', 'MAX.LENGTH_RECTANGULARITY', 'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR', 'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR', 'SKEWNESS_ABOUT_MINOR', 'KURTOSIS_ABOUT_MAJOR', 'KURTOSIS_ABOUT_MINOR', 'HOLLOWS_RATIO', 'Class']
#
# Target Labels of dataset are:
#  ['van' 'saab' 'bus' 'opel']

# %%
#Dataset Label value Count
vehicle['Class'].value_counts()
# Out:
# bus     218
# saab    217
# opel    212
# van     199
# Name: Class, dtype: int64

# %% [markdown]
# ## DataSet Statistics

# %% [markdown]
# By comapring standard deviation and mean your data points, it is observed that our data points are
# almost tend to be close to the means we have few outliers present in the dataset.

# %%
#to check if outliers are present in the data
vehicle.describe()
# Out:
#        COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# count   846.000000   846.000000            846.000000    846.000000
# mean     93.678487    44.861702             82.088652    168.940898
# std       8.234474     6.169866             15.771533     33.472183
# min      73.000000    33.000000             40.000000    104.000000
# 25%      87.000000    40.000000             70.000000    141.000000
# 50%      93.000000    44.000000             80.000000    167.000000
# 75%     100.000000    49.000000             98.000000    195.000000
# max     119.000000    59.000000            112.000000    333.000000
#
#        PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# count            846.000000               846.000000     846.000000
# mean              61.693853                 8.567376     168.839243
# std                7.888251                 4.601217      33.244978
# min               47.000000                 2.000000     112.000000
# 25%               57.000000                 7.000000     146.250000
# 50%               61.000000                 8.000000     157.000000
# 75%               65.000000                10.000000     198.000000
# max              138.000000                55.000000     265.000000
#
#        ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# count     846.000000              846.000000                 846.000000
# mean       40.933806               20.582742                 147.998818
# std         7.811560                2.592138                  14.515652
# min        26.000000               17.000000                 118.000000
# 25%        33.000000               19.000000                 137.000000
# 50%        43.000000               20.000000                 146.000000
# 75%        46.000000               23.000000                 159.000000
# max        61.000000               29.000000                 188.000000
#
#        SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  \
# count             846.000000             846.000000
# mean              188.625296             439.911348
# std                31.394837             176.692614
# min               130.000000             184.000000
# 25%               167.000000             318.250000
# 50%               178.500000             364.000000
# 75%               217.000000             587.000000
# max               320.000000            1018.000000
#
#        SCALED_RADIUS_OF_GYRATION  SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  \
# count                  846.00000            846.000000            846.000000
# mean                   174.70331             72.462175              6.377069
# std                     32.54649              7.486974              4.918353
# min                    109.00000             59.000000              0.000000
# 25%                    149.00000             67.000000              2.000000
# 50%                    173.00000             71.500000              6.000000
# 75%                    198.00000             75.000000              9.000000
# max                    268.00000            135.000000             22.000000
#
#        KURTOSIS_ABOUT_MAJOR  KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO
# count            846.000000            846.000000     846.000000
# mean              12.599291            188.932624     195.632388
# std                8.931240              6.163949       7.438797
# min                0.000000            176.000000     181.000000
# 25%                5.000000            184.000000     190.250000
# 50%               11.000000            188.000000     197.000000
# 75%               19.000000            193.000000     201.000000
# max               41.000000            206.000000     211.000000

# %% [markdown]
# #  Data Visualization

# %% [markdown]
# ## Histogram

# %%
Mvehicle.BarChart(vehicle)
# Out:
# BarChart for analyzing the frequency of Categorical labled class.

# %% [markdown]
# ## Correlation Matrix

# %% [markdown]
# Correlation helps you to find out the relationship between variables. According to Correlation graph,

# %% [markdown]
# -  it can be observed that KURTOSIS_ABOUT_MAJOR AND KUROSIS_ABOUT_MINOR has a little impact on overall data. For the reason these features can be eliminated from the dataset. On the Contraty, SCALED_VARIANCE_MINOR is perfect highly correlated to SCATTER_RATIO, means we can also eliminate one of these two variables.

# %%
Mvehicle.Correlation_matrix(vehicle)
# Out:
# Correlation Analysis

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Label Encoding is used to convert the categorical labels to its numeric representation.

# %%
lencoder = LabelEncoder()
vdataset = Mvehicle.label_encoding(lencoder,vehicle)
vdataset.head()
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42                      20                        159
# 1             45                      19                        143
# 2             32                      23                        158
# 3             46                      19                        143
# 4             45                      19                        144
#
#    SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                    176                    379                        184
# 1                    170                    330                        158
# 2                    223                    635                        220
# 3                    160                    309                        127
# 4                    241                    325                        188
#
#    SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                    70                     6                    16
# 1                    72                     9                    14
# 2                    73                    14                     9
# 3                    63                     6                    10
# 4                   127                     9                    11
#
#    KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO Class  Class_code
# 0                   187            197   van           3
# 1                   189            199   van           3
# 2                   188            196  saab           2
# 3                   199            207   van           3
# 4                   180            183   bus           0

# %% [markdown]
# # Training Model

# %% [markdown]
# Splitting the data into two set in a ratio of 70% for training set and 30% for testing set.

# %%
#Splitting data for training and testing
X_train, X_test, y_train, y_test = Mvehicle.splitting_train_test_data(vdataset , 0.3)

# %%
y_train
# Out:
# 794    0
# 317    2
# 570    2
# 750    2
# 374    3
#       ..
# 725    3
# 607    3
# 544    0
# 643    0
# 414    3
# Name: Class_code, Length: 592, dtype: int32

# %% [markdown]
# # Training Classifier with Logistic Regression

# %%
classifier = Mvehicle.LogisticRegression_train(X_train, y_train)

# %% [markdown]
# # Testing Model and Evaluating Model Performance

# %%
y_predict = Mvehicle.test_classifier(classifier , X_test)
#y_predict

# %%
y_predict = lencoder.inverse_transform(y_predict)
y_test = lencoder.inverse_transform(y_test)

# %%
accuracy =  metrics.accuracy_score(y_test, y_predict)
print("Accuracy: ",accuracy*100)
# Out:
# Accuracy:  79.92125984251969

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
#  According to the above confusion matrix, it is observed that overall the model has not perform good as,

# %% [markdown]
# - For False Positive case, it can be observed that 18 points that are misclassified by the model belongs to "saab" Class, which   is missclassifies as they originally belong to "opel" Class, similarly 20 data points has been missclassified for belonging       to "opel" class, but originally they belong to "saab" class.

# %% [markdown]
# As a result, we can conclude the model is not sucessfully able to classify points between "opel" and "saab" class.

# %%
cmatrix = Mvehicle.model_confusion_matrix(y_test , y_predict , vehicle)

# %% [markdown]
# # Visualization of Misclassification

# %% [markdown]
# The below stacked bar chart represents the misclassified points of Logistic Regression Classifier. Our model is not able to distinguish
# well between the <b> saab </b> and <b> opel </b> class as shown in the graph.

# %%
visualize.Misclasssification_visualization(y_test, y_predict,vehicle)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          bus       0.96      0.92      0.94        77
#         opel       0.66      0.68      0.67        65
#         saab       0.63      0.58      0.61        57
#          van       0.90      1.00      0.95        55
#
#     accuracy                           0.80       254
#    macro avg       0.79      0.79      0.79       254
# weighted avg       0.80      0.80      0.80       254

# %% [markdown]
# # Cross Validation Score

# %% [markdown]
# KFold Cross Validation is used for evaluation of Logistic Regression. For this, I have used 10-Fold cross validation where the dataset will be splitted into 10 folds.

# %%
#Cross Validation Score For Logistic Regression Classifier
cv = Mvehicle.cross_validation(vdataset , classifier)
print("Cross Validation Score: ",cv)
# Out:
# Cross Validation Score:  0.7909965397910561

# %% [markdown]
# Since Cross Validation Score is less than accuracy which is 80%, we would further try tuning the hyper-parameters of Logistic Regression for better results.

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Model Evaluation is done for determinig the accuracy of differnet classifiers using KFold Cross Validation.
# For this Purpose Folloing classifiers are used:
#     - Logistic Regression
#     - K-Nearest Neighbors
#     - Decision Tree
#     - Gausian NaiveBayes
#     - Support Vector Machine
#     - Random Forest

# %% [markdown]
# According to the graph shown below, we can compare the range and distribution of the accuracy for each model.
# As shown, we can conclude that SVM and Logistic Regression classifiers performance will be better as compare to other classifiers.

# %%
model.Evaluation_model(vdataset)

# %% [markdown]
# # Training Model with Support Vectore Machine

# %% [markdown]
# Performing Hyper-Parameters tuning of Support Vectore Machine using GridSearch techniuqe with cv= 5

# %%
svm_classifier = model.SVM_train(X_train,y_train,5)
model_classifier = svm_classifier.fit(X_train, y_train)

# %%
y_predict = Mvehicle.test_classifier(model_classifier , X_test)

# %%
y_predict = lencoder.inverse_transform(y_predict)

# %%
accuracy =  metrics.accuracy_score(y_test, y_predict)
print("Accuracy: ",accuracy*100)
# Out:
# Accuracy:  78.34645669291339

# %% [markdown]
# Accuracy with Support Vector Machine is 78% , which is not comparatively good than Logistic Regression that is 80% even after tuning the hyperparameters of Logistic Regression. Further I would be using other comparative techniques to evaluate model, For now I have used Support Vectore Machine classifier which altogether has not been a good model for this dataset.

# %% [markdown]
# # Visualization of Misclasssification

# %% [markdown]
# The below stacked bar chart represents the misclassified points of Support Vector Machine Classifier. This model is also not able to distinguish well between the <b> saab </b> and <b> opel </b> class and mixing both of them. As it can be observed from the graph that the false positive ratio of <b> saab </b> and <b> opel </b> is maximum as compare to other classes.

# %%
visualize.Misclasssification_visualization(y_test, y_predict,vdataset)

# %% [markdown]
# # Conclusion

# %% [markdown]
# By comparing the misclassification of both of the classifiers <b> Logistic Regression </b> and
# <b> Support Vector Machine </b> we can conclude overall our model is not able to classify between <b> saab </b>
# and <b> opel </b> class. We might be missing some details in the dataset. Further I would look in the dataset and
# try to find the problem as to why our model is overfitting the data.

# %% [markdown]
# # Traversal Of Train Test Split

# %% [markdown]
# In Train Test Split Traversal, an evaluation metric is computed for <b> Support Vector Machine </b> with different split ratio of train and test set using repeated <b> K-Fold Cross-Validation </b>. Further a <b> Line Plot </b> is drawn for each split ratio for traing and testing set with it's corresponding performance score.

# %% [markdown]
# ## Visualization of Train Test Split Traversal

# %%
split_matrix = train_test_split.train_test_split_traversal(svm_classifier , vdataset)
# Out:
# ------------------------------------------------------------------
# Line plot with Training size =  80.0 % and Testing Size = 20.0 %.
# ------------------------------------------------------------------
# Line plot with Training size =  70.0 % and Testing Size = 30.0 %.
# ------------------------------------------------------------------
# Line plot with Training size =  60.0 % and Testing Size = 40.0 %.
# ------------------------------------------------------------------
# Line plot with Training size =  50.0 % and Testing Size = 50.0 %.
# ------------------------------------------------------------------
# Line plot with Training size =  40.0 % and Testing Size = 60.0 %.
# ------------------------------------------------------------------
# Line plot with Training size =  30.0 % and Testing Size = 70.0 %.
# ------------------------------------------------------------------
# Line plot with Training size =  20.0 % and Testing Size = 80.0 %.
# ------------------------------------------------------------------
# Line plot with Training size =  10.0 % and Testing Size = 90.0 %.

# %% [markdown]
# ## Performance score with different train and test split proportion

# %%
split_matrix.head(20)
# Out:
#     KFold  Training_Set  Testing_Set   Accuracy
# 0     2.0          80.0         20.0  78.547920
# 1     3.0          80.0         20.0  80.029619
# 2     4.0          80.0         20.0  83.140389
# 3     5.0          80.0         20.0  82.269041
# 4     6.0          80.0         20.0  83.592457
# 5     7.0          80.0         20.0  82.861899
# 6     8.0          80.0         20.0  82.848773
# 7     9.0          80.0         20.0  83.596068
# 8    10.0          80.0         20.0  83.136846
# 9    11.0          80.0         20.0  81.674900
# 10   12.0          80.0         20.0  81.961785
# 11   13.0          80.0         20.0  82.419952
# 12   14.0          80.0         20.0  82.104609
# 13   15.0          80.0         20.0  81.675114
# 14    2.0          70.0         30.0  77.540946
# 15    3.0          70.0         30.0  81.420807
# 16    4.0          70.0         30.0  81.081798
# 17    5.0          70.0         30.0  82.938814
# 18    6.0          70.0         30.0  81.449050
# 19    7.0          70.0         30.0  80.762512

# %% [markdown]
# After traversing through different splits ratio of train and test set using repeated K-Fold Cross-Validation, It can be concluded that <b> Support Vector Machine</b> works better with a split ratio of <b> 80% </b> for training and <b> 20% </b> for testing with k=9 and gives the highest accuracy of <b> 83.5% .</b>

# %% [markdown]
# # Training SVM Classifier after changing the train and test split ratio

# %% [markdown]
# Splitting the data into two set in a ratio of 80% for training set and 20% for testing set

# %%
X_train, X_test, y_train, y_test = Mvehicle.splitting_train_test_data(vdataset , 0.2)

# %%
classifier = model.SVM_train(X_train,y_train , 9)
model_classifier = classifier.fit(X_train, y_train)

# %%
y_predict = Mvehicle.test_classifier(model_classifier , X_test)

# %%
##changing numerical labels to categorical labesl
y_predict = lencoder.inverse_transform(y_predict)
y_test = lencoder.inverse_transform(y_test)

# %% [markdown]
# ## Classification Report

# %%
print(classification_report(y_test, y_predict ))
# Out:
#               precision    recall  f1-score   support
#
#          bus       0.98      0.96      0.97        46
#         opel       0.65      0.61      0.63        46
#         saab       0.64      0.68      0.66        44
#          van       0.91      0.94      0.93        34
#
#     accuracy                           0.79       170
#    macro avg       0.80      0.80      0.80       170
# weighted avg       0.79      0.79      0.79       170

# %% [markdown]
# ## Visualization of SVM missclassifier after changing train/test split ratio

# %%
visualize.Misclasssification_visualization(y_test, y_predict,vdataset)

# %% [markdown]
# # Consclusion:

# %% [markdown]
# After going through the traversal of train and test split ratio using repeated using K-Fold, and according to the above visualization we can observed that by changing the ratio of testset = 20% and trainingset to 80% with k=9 , Accuracy of the classifier has only increased by 1% which is not that much good also it has not made improvemnets in classifying <b> Class:opel </b> but for <b> Class:saab </b> the misclassification points has been reduced.
