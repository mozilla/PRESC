# %% [markdown]
# # Loading Dataset from Vehicle.csv

# %%
#importing python libraries
import pandas as pd
import modules as Mvehicle 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
vehicle = pd.read_csv('../../datasets/vehicles.csv')

# %% [markdown]
# # Exploring Vehicle Data Set

# %%
vehicle.head(5)
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42                      20                        159
# ...

# %%
Mvehicle.dataset_statistics(vehicle)
# Out:
# Shape of the dataset:  (846, 19)
#
# Features of the dataset are:  ['COMPACTNESS', 'CIRCULARITY', 'DISTANCE_CIRCULARITY', 'RADIUS_RATIO', 'PR.AXIS_ASPECT_RATIO', 'MAX.LENGTH_ASPECT_RATIO', 'SCATTER_RATIO', 'ELONGATEDNESS', 'PR.AXIS_RECTANGULARITY', 'MAX.LENGTH_RECTANGULARITY', 'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR', 'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR', 'SKEWNESS_ABOUT_MINOR', 'KURTOSIS_ABOUT_MAJOR', 'KURTOSIS_ABOUT_MINOR', 'HOLLOWS_RATIO', 'Class']
#
# Target Labels of dataset are:  ['van' 'saab' 'bus' 'opel']

# %%
#Dataset Label value Count
vehicle['Class'].value_counts()
# Out:
# bus     218
# saab    217
# opel    212
# van     199
# Name: Class, dtype: int64

# %%
#to check if outliers are present in the data
vehicle.describe()
# Out:
#        COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# count   846.000000   846.000000            846.000000    846.000000
# mean     93.678487    44.861702             82.088652    168.940898
# std       8.234474     6.169866             15.771533     33.472183
# min      73.000000    33.000000             40.000000    104.000000
# 25%      87.000000    40.000000             70.000000    141.000000
# 50%      93.000000    44.000000             80.000000    167.000000
# 75%     100.000000    49.000000             98.000000    195.000000
# max     119.000000    59.000000            112.000000    333.000000
#
#        PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# count            846.000000               846.000000     846.000000
# mean              61.693853                 8.567376     168.839243
# std                7.888251                 4.601217      33.244978
# min               47.000000                 2.000000     112.000000
# ...

# %% [markdown]
# #  Data Visualization

# %%
Mvehicle.data_visualization(vehicle)
# Out:
# Histogram for analyzing the frequency of labled class.
#
#
#
# Correlation Analysis.

# %% [markdown]
# Correlation helps you to find out the relationship between variables. According to Correlation graph, it can be observed that KURTOSIS_ABOUT_MAJOR AND KUROSIS_ABOUT_MINOR has a little impact on overall data. For the reason these features can be eliminated from the dataset. On the Contraty, SCALED_VARIANCE_MINOR is perfect highly correlated to SCATTER_RATIO, means we can also eliminate one of these two variables.

# %% [markdown]
# # Label Encoding

# %%
#converting categorical labels into numeric values
vdataset = vehicle.copy()
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
vdataset['Class_code'] = lb_make.fit_transform(vehicle['Class'])

vdataset.head()
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42                      20                        159
# ...

# %% [markdown]
# # Training Model

# %%
from sklearn.model_selection import train_test_split

# %%
#Splitting data for training and testing
X_train, X_test, y_train, y_test = Mvehicle.splitting_train_test_data(vdataset)

# %%
# scaling data
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = Mvehicle.LogisticRegression_train(X_train,y_train)

# %% [markdown]
# # Testing Model and Evaluating Model Performance

# %%
y_predict = Mvehicle.test_classifier(classifier , X_test)
#y_predict

# %%
from sklearn.metrics import classification_report , confusion_matrix
from sklearn import metrics


accuracy =  metrics.accuracy_score(y_test, y_predict)
print("Accuracy: ",accuracy*100)
# Out:
# Accuracy:  78.74015748031496

# %%
# Confusion Matrix

cmatrix = Mvehicle.model_confusion_matrix(y_test , y_predict , dataset_sklearn)

# %% [markdown]
#  According to the above confusion matrix, it is observed that overall the model has not perform good as,

# %% [markdown]
# - For False Positive case, most of the data points that are misclassified by the model belongs to "saab" Class, which is           missclassifies as they originally belong to "opel" Class, similarly 17 data points has been missclassified for belonging       to "opel" class, but originally they belong to "saab" class.

# %% [markdown]
# As a result, we can conclude the model is not sucessfully able to classify points between "opel" and "saab" class.

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93        77
#            1       0.68      0.58      0.63        65
#            2       0.64      0.65      0.64        57
#            3       0.82      1.00      0.90        55
#
#     accuracy                           0.79       254
#    macro avg       0.77      0.79      0.78       254
# weighted avg       0.79      0.79      0.78       254

# %% [markdown]
# # Cross Validation Score

# %%
X = dataset_sklearn.drop(['Class' , 'Class_code'], axis = 1)
y = dataset_sklearn[['Class_code']]

# %%
cv = Mvehicle.cross_validation(X,y,classifier)
print("Cross Validation Score: ",cv)
# Out:
# Cross Validation Score:  0.7912774827676179

# %% [markdown]
# Since Cross Validation Score is more than accuracy which is 78.7% it means model is overfitted.

# %% [markdown]
# # Tuning Parameters of Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LRclassifier = Mvehicle.Tuning_LogiticRegression(X_train,y_train, 10)

# %%
LRy_predict = Mvehicle.test_classifier(LRclassifier , X_test)

# %%
accuracy =  metrics.accuracy_score(y_test, LRy_predict)
print("Accuracy: ",accuracy*100)
# Out:
# Accuracy:  79.13385826771653

# %% [markdown]
# After tuning parameters of Logisic Regrssion , it can be observed that even after finding best parameters and again testing model has not been improved.

# %% [markdown]
# # Learning Curve Graph

# %%
X2 = np.array(X)
y2 = np.array(y)

#randomize the data before drawing the Learning Curves
X2, y2 = Mvehicle.randomize_data(X2, y2)

# %%
# Logistic Regression
estimator = LogisticRegression()
Mvehicle.draw_learning_curves(X2, y2, estimator, 25)

# %%
#Support Vector Machine

from sklearn.svm import SVC
estimator = SVC(C=1000, cache_size=200, degree=3, gamma=0.0001, kernel='rbf')
Mvehicle.draw_learning_curves(X2, y2, estimator, 25)

# %%
# RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier
estimator = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
Mvehicle.draw_learning_curves(X2, y2, estimator, 25)

# %%
# Decision Tree

from sklearn.ensemble import GradientBoostingClassifier
estimator = GradientBoostingClassifier()
Mvehicle.draw_learning_curves(X2, y2, estimator, 25)

# %% [markdown]
# #
# from sklearn.naive_bayes import GaussianNB
# estimator = GaussianNB()
# Mvehicle.draw_learning_curves(X2, y2, estimator, 25)

# %% [markdown]
# # Training Model with Support Vectore MAchine

# %%
#from sklearn.svm import SVC
classifier = Mvehicle.SVM_train(X_train,y_train)
classifier = classifier.fit(X_train , y_train)

# %%
y_predict = Mvehicle.test_classifier(classifier , X_test)

# %%
accuracy =  metrics.accuracy_score(y_test, y_predict)
print("Accuracy: ",accuracy*100)
# Out:
# Accuracy:  80.70866141732283

# %% [markdown]
# Accuracy with Support Vector Machine is 80% , which is not comparatively good than Logistic Regression which was 79% after tuning the hyperparameters of Logistic Regression. Further I would be using other comparative techniques to evaluate model, For now I have used Support Vectore Machine and according to its learnign curve its traing score is less than logistic regression's score which is an overfit model.
