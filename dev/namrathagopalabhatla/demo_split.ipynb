# %%
import warnings
from data_processing import read_data
from train_test_splitting import split_variation

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset:
# Function ***read_data*** is used to read the data from the file located at the path provided. Here, I have used the ***vehicles.csv*** dataset.

# %%
X, y, class_map, _, _ = read_data('../../datasets/vehicles.csv')
# Out:
#   Mapping
# 0     bus
# 1    opel
# 2    saab
# 3     van

# %% [markdown]
# ## Train and Test Split:
# Function ***split_function*** is used to split the dataset into training and testing datasets, where we get information about the evaluation metrics, that is, the accuracy and F1-Score, when the LR classifier is trained using a given split. The below experiments try 3 different splits and the evaluation metrics change with each split:
# - Steps of 5% (5 - 95%)
# - Steps of 10% (10 - 90%)
# - Steps of 20% (20 - 80%)

# %% [markdown]
# ### Variation in 5% steps

# %%
split_variation(X, y)
# Out:
#     Train size (%)  Training Accuracy  Training F1-Score  Testing Accuracy  \
# 0              5.0           0.857143           0.857143          0.624378
# 1             10.0           0.738095           0.728467          0.641732
# 2             15.0           0.698413           0.696140          0.647222
# 3             20.0           0.745562           0.742620          0.688331
# 4             25.0           0.772512           0.768104          0.685039
# 5             30.0           0.762846           0.757138          0.694772
# 6             35.0           0.760135           0.752860          0.718182
# 7             40.0           0.775148           0.769611          0.677165
# 8             45.0           0.742105           0.734085          0.686695
# 9             50.0           0.704492           0.693624          0.739953
# 10            55.0           0.744086           0.738926          0.706037
# ...

# %% [markdown]
# ### Variation in 10% steps

# %%
split_variation(X, y, 0.1)
# Out:
#    Train size (%)  Training Accuracy  Training F1-Score  Testing Accuracy  \
# 0            10.0           0.797619           0.791381          0.631234
# 1            20.0           0.763314           0.762427          0.672083
# 2            30.0           0.731225           0.721191          0.693086
# 3            40.0           0.739645           0.731590          0.702756
# 4            50.0           0.737589           0.731125          0.692671
# 5            60.0           0.723866           0.718603          0.699115
# 6            70.0           0.751689           0.744756          0.724409
# 7            80.0           0.732249           0.726393          0.752941
# 8            90.0           0.750329           0.745159          0.658824
#
#    Testing F1-Score
# 0          0.626445
# 1          0.674293
# 2          0.689245
# 3          0.696382
# 4          0.686440
# 5          0.693335
# 6          0.719438
# 7          0.751458
# 8          0.649342

# %% [markdown]
# ### Variation in 20% steps

# %%
split_variation(X, y, 0.2)
# Out:
#    Train size (%)  Training Accuracy  Training F1-Score  Testing Accuracy  \
# 0            20.0           0.733728           0.725641          0.679468
# 1            40.0           0.757396           0.752784          0.677165
# 2            60.0           0.715976           0.708017          0.713864
# 3            80.0           0.733728           0.726484          0.682353
#
#    Testing F1-Score
# 0          0.676286
# 1          0.668538
# 2          0.707101
# 3          0.672629
