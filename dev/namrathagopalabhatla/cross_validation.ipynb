# %%
import warnings
from data_processing import read_data
from cross_validation import cross_validation_variation

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset:
# Function ***read_data*** is used to read the data from the file located at the path provided. Here, I have used the ***vehicles.csv*** dataset.

# %%
X, y, class_map, _, _ = read_data('../../datasets/vehicles.csv')
# Out:
#   Mapping
# 0     bus
# 1    opel
# 2    saab
# 3     van

# %% [markdown]
# ## K-Fold Validation Splits:
# Function ***cross_validation_variation*** is used to perform K-Fold validation on the LR classifier that is trained on the given dataset. The below experiments try 3 ranges of splits and the evaluation metric used is accuracy:
# - Range: 2-15, Step: 1
# - Range: 2-15, Step: 2
# - Range: 2-20, Step: 2
#
# The function displays a table of the mean metric, and shows a plot the plots the same data displayed by the table.

# %% [markdown]
# ### Range 2-15 with Step as 1

# %%
cross_validation_variation(X, y, (2, 15, 1))
# Out:
#     Splits  Mean Accuracy
# 0        2       0.684397
# 1        3       0.722222
# 2        4       0.721022
# 3        5       0.708040
# 4        6       0.705674
# 5        7       0.712761
# 6        8       0.718744
# 7        9       0.724586
# 8       10       0.715182
# 9       11       0.721090
# 10      12       0.716348
# 11      13       0.717518
# 12      14       0.717584

# %% [markdown]
# ### Range 2-15 with Step as 2

# %%
cross_validation_variation(X, y, (2, 15, 2))
# Out:
#    Splits  Mean Accuracy
# 0       2       0.684397
# 1       4       0.721022
# 2       6       0.705674
# 3       8       0.718744
# 4      10       0.715182
# 5      12       0.716348
# 6      14       0.717584

# %% [markdown]
# ### Range 2-20 with Step as 2

# %%
cross_validation_variation(X, y, (2, 20, 2))
# Out:
#    Splits  Mean Accuracy
# 0       2       0.684397
# 1       4       0.721022
# 2       6       0.705674
# 3       8       0.718744
# 4      10       0.715182
# 5      12       0.716348
# 6      14       0.717584
# 7      16       0.727005
# 8      18       0.722222
