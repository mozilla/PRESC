# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

data = pd.read_csv("../../../datasets/winequality.csv")

x_features= data.drop(["quality"],axis=1)

x_features= x_features.drop(["recommend"],axis=1)
x_labels=data["recommend"]

# print(type(x_features))

x_train,x_test,y_train,y_test = train_test_split(x_features,x_labels,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

# %%
import importance_score as imp_s
imp_s.imp_score_singular_datapoints(rfc,np.array(x_train),np.array(y_train),np.array(x_test),np.array(y_test), 10, 16)
